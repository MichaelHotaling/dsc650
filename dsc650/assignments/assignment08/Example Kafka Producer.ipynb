# %%
import json
import uuid
import pandas as pd
import time

from kafka import KafkaProducer, KafkaAdminClient
from kafka.admin.new_topic import NewTopic
from kafka.errors import TopicAlreadyExistsError

# %% [markdown]
# ### Configuration Parameters
#
# > **TODO:** Change the configuration prameters to the appropriate values for your setup.

# %%
config = dict(
    bootstrap_servers=['kafka.kafka.svc.cluster.local:9092'],
    first_name='Michael',
    last_name='Hotaling'
)

config['client_id'] = '{}{}'.format(
    config['last_name'], 
    config['first_name']
)
config['topic_prefix'] = '{}{}'.format(
    config['last_name'], 
    config['first_name']
)

config
# Out:
# {'bootstrap_servers': ['kafka.kafka.svc.cluster.local:9092'],
#  'first_name': 'Michael',
#  'last_name': 'Hotaling',
#  'client_id': 'HotalingMichael',
#  'topic_prefix': 'HotalingMichael'}

# %% [markdown]
# ### Create Topic Utility Function
#
# The `create_kafka_topic` helps create a Kafka topic based on your configuration settings.  For instance, if your first name is *John* and your last name is *Doe*, `create_kafka_topic('locations')` will create a topic with the name `DoeJohn-locations`.  The function will not create the topic if it already exists.

# %%
def create_kafka_topic(topic_name, config=config, num_partitions=1, replication_factor=1):
    bootstrap_servers = config['bootstrap_servers']
    client_id = config['client_id']
    topic_prefix = config['topic_prefix']
    name = '{}-{}'.format(topic_prefix, topic_name)
    
    admin_client = KafkaAdminClient(
        bootstrap_servers=bootstrap_servers, 
        client_id=client_id
    )
    
    topic = NewTopic(
        name=name,
        num_partitions=num_partitions,
        replication_factor=replication_factor
    )

    topic_list = [topic]
    try:
        admin_client.create_topics(new_topics=topic_list)
        print('Created topic "{}"'.format(name))
    except TopicAlreadyExistsError as e:
        print('Topic "{}" already exists'.format(name))
    
create_kafka_topic('locations')
create_kafka_topic('accelerations')
# Out:
# Topic "HotalingMichael-locations" already exists
# Topic "HotalingMichael-accelerations" already exists

# %% [markdown]
# ### Kafka Producer
#
# The following code creates a `KafkaProducer` object which you can use to send Python objects that are serialized as JSON.
#
# **Note:** This producer serializes Python objects as JSON. This means that object must be JSON serializable.  As an example, Python `DateTime` values are not JSON serializable and must be converted to a string (e.g. ISO 8601) or a numeric value (e.g. a Unix timestamp) before being sent.

# %%
producer = KafkaProducer(
  bootstrap_servers=config['bootstrap_servers'],
  value_serializer=lambda x: json.dumps(x).encode('utf-8')
)

# %% [markdown]
# ### Send Data Function
#
# The `send_data` function sends a Python object to a Kafka topic. This function adds the `topic_prefix` to the topic so `send_data('locations', data)` sends a JSON serialized message to `DoeJohn-locations`. The function also registers callbacks to let you know if the message has been sent or if an error has occured.

# %%
def on_send_success(record_metadata):
    print('Message sent:\n    Topic: "{}"\n    Partition: {}\n    Offset: {}'.format(
        record_metadata.topic,
        record_metadata.partition,
        record_metadata.offset
    ))
    
def on_send_error(excp):
    print('I am an errback', exc_info=excp)
    # handle exception

def send_data(topic, data, config=config, producer=producer, msg_key=None):
    topic_prefix = config['topic_prefix']
    topic_name = '{}-{}'.format(topic_prefix, topic)
    
    if msg_key is not None:
        key = msg_key
    else:
        key = uuid.uuid4().hex
    
    producer.send(
        topic_name, 
        value=data,
        key=key.encode('utf-8')
    ).add_callback(on_send_success).add_errback(on_send_error)

# %%
example_data = dict(
    key1='value1',
    key2='value2'
)
send_data('locations', example_data)
send_data('accelerations', example_data)

# %%
#Writing data in for the next examples
send_data('joined', example_data)
send_data('simple', example_data)
send_data('windowed', example_data)
# Out:
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 224
# Message sent:
#     Topic: "HotalingMichael-locations"
#     Partition: 0
#     Offset: 14
# Message sent:
#     Topic: "HotalingMichael-joined"
#     Partition: 0
#     Offset: 2
# Message sent:
#     Topic: "HotalingMichael-simple"
#     Partition: 0
#     Offset: 2
# Message sent:
#     Topic: "HotalingMichael-windowed"
#     Partition: 0
#     Offset: 2

# %% [markdown]
# # Location Data

# %%
import os
from pathlib import Path

# %%
current_dir = Path(os.getcwd()).absolute()
current_dir = Path(current_dir).parents[2]
data_dir = current_dir.joinpath('data')
processed_dir = data_dir.joinpath('processed')
bdd_dir = processed_dir.joinpath('bdd')
locations_dir = bdd_dir.joinpath('locations')
accelerations_dir = bdd_dir.joinpath('accelerations')
locations_dir
# Out:
# PosixPath('/home/jovyan/dsc650-master/data/processed/bdd/locations')

# %%
df_locations = pd.read_parquet(locations_dir).sort_values('offset').reset_index()
df_locations.timestamp = df_locations.timestamp.dt.strftime('%Y-%m-%d %H:%M:%S.%f')
df_dict_locations = df_locations.to_dict(orient='records')

# %%
df_locations.head(5)
# Out:
#    index                                id                           ride_id  \
# 0      1  85c61911b7fe2ced1000c33c9e932706  6760ffa3f41908695d1405b776c3e8d5
# 1      0  58682c5d48cad9d9e103431d773615bf  c9a2b46c9aa515b632eddc45c4868482
# 2      2  58682c5d48cad9d9e103431d773615bf  c9a2b46c9aa515b632eddc45c4868482
# 3      3  85c61911b7fe2ced1000c33c9e932706  6760ffa3f41908695d1405b776c3e8d5
# 4      5  85c61911b7fe2ced1000c33c9e932706  6760ffa3f41908695d1405b776c3e8d5
#
#                                uuid                   timestamp    offset  \
# 0  dad7eae44e784b549c8c5a3aa051a8c7  1970-01-01 00:25:07.320453  1.077913
# 1  19b9aa10588646b3bf22c9b4865a7995  1970-01-01 00:25:03.882586  1.525061
# 2  19b9aa10588646b3bf22c9b4865a7995  1970-01-01 00:25:03.882583  4.525061
# 3  dad7eae44e784b549c8c5a3aa051a8c7  1970-01-01 00:25:07.320449  5.077913
# 4  dad7eae44e784b549c8c5a3aa051a8c7  1970-01-01 00:25:07.320446  8.077913
#
#        course   latitude  longitude       geohash  speed  accuracy  timelapse  \
# 0  158.203125  40.677641 -73.817930  dr5x2jpkmtcy   2.12      10.0      False
# 1  299.619141  40.762870 -73.961949  dr5ruuwscttz   0.00      10.0      False
# 2  299.619141  40.762870 -73.961949  dr5ruuwsctv3   0.00      10.0      False
# 3  159.960938  40.677883 -73.818047  dr5x2jpmfffw  11.75      10.0      False
# 4  159.609375  40.678191 -73.818193  dr5x2jppxkqj  13.15      10.0      False
#
#                                    filename      t
# 0  d745b92f-aefd-467d-9121-7a71308e8d6d.mov  000.0
# 1  e2f795a7-6a7d-4500-b5d7-4569de996811.mov  000.0
# 2  e2f795a7-6a7d-4500-b5d7-4569de996811.mov  004.5
# 3  d745b92f-aefd-467d-9121-7a71308e8d6d.mov  004.5
# 4  d745b92f-aefd-467d-9121-7a71308e8d6d.mov  007.8

# %%
df_dict_locations[0]
# Out:
# {'index': 1,
#  'id': '85c61911b7fe2ced1000c33c9e932706',
#  'ride_id': '6760ffa3f41908695d1405b776c3e8d5',
#  'uuid': 'dad7eae44e784b549c8c5a3aa051a8c7',
#  'timestamp': '1970-01-01 00:25:07.320453',
#  'offset': 1.0779125295566454,
#  'course': 158.203125,
#  'latitude': 40.677641336844,
#  'longitude': -73.81793000742218,
#  'geohash': 'dr5x2jpkmtcy',
#  'speed': 2.119999885559082,
#  'accuracy': 10.0,
#  'timelapse': False,
#  'filename': 'd745b92f-aefd-467d-9121-7a71308e8d6d.mov',
#  't': '000.0'}

# %%
def send_location_data(index):
    payload = df_dict_locations[index]
    send_data('locations', payload)

# %%
last_offset = 0
for index,row in df_locations.iterrows():
    current_offset = row['offset']
    time.sleep(current_offset - last_offset)
    send_location_data(index)
    last_offset = current_offset
# Out:
# Message sent:
#     Topic: "HotalingMichael-locations"
#     Partition: 0
#     Offset: 15
# Message sent:
#     Topic: "HotalingMichael-locations"
#     Partition: 0
#     Offset: 16
# Message sent:
#     Topic: "HotalingMichael-locations"
#     Partition: 0
#     Offset: 17
# Message sent:
#     Topic: "HotalingMichael-locations"
#     Partition: 0
#     Offset: 18
# Message sent:
#     Topic: "HotalingMichael-locations"
#     Partition: 0
#     Offset: 19
# Message sent:
#     Topic: "HotalingMichael-locations"
#     Partition: 0
#     Offset: 20
# Message sent:
#     Topic: "HotalingMichael-locations"
#     Partition: 0
#     Offset: 21
# Message sent:
#     Topic: "HotalingMichael-locations"
#     Partition: 0
#     Offset: 22
# Message sent:
#     Topic: "HotalingMichael-locations"
#     Partition: 0
#     Offset: 23
# Message sent:
#     Topic: "HotalingMichael-locations"
#     Partition: 0
#     Offset: 24
# Message sent:
#     Topic: "HotalingMichael-locations"
#     Partition: 0
#     Offset: 25
# Message sent:
#     Topic: "HotalingMichael-locations"
#     Partition: 0
#     Offset: 26
# Message sent:
#     Topic: "HotalingMichael-locations"
#     Partition: 0
#     Offset: 27
# Message sent:
#     Topic: "HotalingMichael-locations"
#     Partition: 0
#     Offset: 28
# Message sent:
#     Topic: "HotalingMichael-locations"
#     Partition: 0
#     Offset: 29
# Message sent:
#     Topic: "HotalingMichael-locations"
#     Partition: 0
#     Offset: 30
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-e40f1a71116b> in <module>
#       2 for index,row in df_locations.iterrows():
#       3     current_offset = row['offset']
# ----> 4     time.sleep(current_offset - last_offset)
#       5     send_location_data(index)
#       6     last_offset = current_offset
#
# KeyboardInterrupt:

# %% [markdown]
# # Accelerations Data

# %%
create_kafka_topic('accelerations')
# Out:
# Topic "HotalingMichael-accelerations" already exists

# %%
df_accelerations = pd.read_parquet(accelerations_dir).sort_values('offset').reset_index()
df_accelerations.timestamp = df_accelerations.timestamp.dt.strftime('%Y-%m-%d %H:%M:%S.%f')
df_dict_accelerations = df_accelerations.to_dict(orient='records')

# %%
df_accelerations.head(5)
# Out:
#    index                                id                           ride_id  \
# 0      0  58682c5d48cad9d9e103431d773615bf  c9a2b46c9aa515b632eddc45c4868482
# 1      1  58682c5d48cad9d9e103431d773615bf  c9a2b46c9aa515b632eddc45c4868482
# 2      2  58682c5d48cad9d9e103431d773615bf  c9a2b46c9aa515b632eddc45c4868482
# 3      3  58682c5d48cad9d9e103431d773615bf  c9a2b46c9aa515b632eddc45c4868482
# 4      4  58682c5d48cad9d9e103431d773615bf  c9a2b46c9aa515b632eddc45c4868482
#
#                                uuid                   timestamp    offset  \
# 0  19b9aa10588646b3bf22c9b4865a7995  1970-01-01 00:25:03.882586  0.822061
# 1  19b9aa10588646b3bf22c9b4865a7995  1970-01-01 00:25:03.882586  0.842061
# 2  19b9aa10588646b3bf22c9b4865a7995  1970-01-01 00:25:03.882586  0.862061
# 3  19b9aa10588646b3bf22c9b4865a7995  1970-01-01 00:25:03.882586  0.882061
# 4  19b9aa10588646b3bf22c9b4865a7995  1970-01-01 00:25:03.882586  0.902061
#
#        x      y      z  timelapse                                  filename  \
# 0 -0.994  0.045 -0.036      False  e2f795a7-6a7d-4500-b5d7-4569de996811.mov
# 1 -0.998  0.046 -0.040      False  e2f795a7-6a7d-4500-b5d7-4569de996811.mov
# 2 -0.999  0.047 -0.036      False  e2f795a7-6a7d-4500-b5d7-4569de996811.mov
# 3 -0.999  0.045 -0.034      False  e2f795a7-6a7d-4500-b5d7-4569de996811.mov
# 4 -0.999  0.048 -0.033      False  e2f795a7-6a7d-4500-b5d7-4569de996811.mov
#
#        t
# 0  000.0
# 1  000.0
# 2  000.0
# 3  000.0
# 4  000.0

# %%
df_dict_accelerations[0]
# Out:
# {'index': 0,
#  'id': '58682c5d48cad9d9e103431d773615bf',
#  'ride_id': 'c9a2b46c9aa515b632eddc45c4868482',
#  'uuid': '19b9aa10588646b3bf22c9b4865a7995',
#  'timestamp': '1970-01-01 00:25:03.882586',
#  'offset': 0.8220608865228429,
#  'x': -0.994,
#  'y': 0.045,
#  'z': -0.036000000000000004,
#  'timelapse': False,
#  'filename': 'e2f795a7-6a7d-4500-b5d7-4569de996811.mov',
#  't': '000.0'}

# %%
def send_acceleration_data(index):
    payload = df_dict_accelerations[index]
    send_data('accelerations', payload)

# %%
last_offset = 0
for index,row in df_accelerations.iterrows():
    current_offset = row['offset']
    time.sleep(current_offset - last_offset)
    send_acceleration_data(index)
    last_offset = current_offset
# Out:
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 225
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 226
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 227
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 228
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 229
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 230
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 231
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 232
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 233
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 234
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 235
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 236
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 237
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 238
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 239
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 240
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 241
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 242
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 243
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 244
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 245
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 246
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 247
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 248
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 249
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 250
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 251
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 252
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 253
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 254
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 255
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 256
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 257
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 258
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 259
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 260
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 261
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 262
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 263
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 264
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 265
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 266
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 267
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 268
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 269
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 270
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 271
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 272
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 273
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 274
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 275
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 276
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 277
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 278
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 279
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 280
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 281
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 282
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 283
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 284
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 285
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 286
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 287
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 288
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 289
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 290
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 291
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 292
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 293
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 294
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 295
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 296
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 297
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 298
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 299
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 300
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 301
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 302
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 303
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 304
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 305
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 306
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 307
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 308
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 309
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 310
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 311
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 312
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 313
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 314
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 315
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 316
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 317
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 318
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 319
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 320
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 321
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 322
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 323
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 324
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 325
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 326
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 327
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 328
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 329
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 330
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 331
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 332
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 333
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 334
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 335
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 336
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 337
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 338
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 339
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 340
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 341
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 342
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 343
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 344
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 345
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 346
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 347
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 348
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 349
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 350
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 351
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 352
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 353
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 354
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 355
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 356
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 357
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 358
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 359
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 360
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 361
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 362
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 363
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 364
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 365
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 366
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 367
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 368
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 369
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 370
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 371
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 372
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 373
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 374
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 375
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 376
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 377
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 378
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 379
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 380
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 381
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 382
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 383
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 384
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 385
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 386
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 387
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 388
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 389
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 390
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 391
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 392
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 393
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 394
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 395
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 396
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 397
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 398
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 399
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 400
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 401
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 402
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 403
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 404
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 405
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 406
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 407
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 408
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 409
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 410
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 411
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 412
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 413
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 414
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 415
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 416
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 417
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 418
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 419
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 420
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 421
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 422
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 423
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 424
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 425
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 426
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 427
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 428
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 429
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 430
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 431
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 432
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 433
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 434
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 435
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 436
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 437
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 438
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 439
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 440
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 441
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 442
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 443
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 444
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 445
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 446
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 447
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 448
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 449
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 450
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 451
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 452
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 453
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 454
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 455
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 456
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 457
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 458
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 459
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 460
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 461
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 462
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 463
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 464
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 465
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 466
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 467
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 468
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 469
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 470
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 471
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 472
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 473
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 474
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 475
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 476
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 477
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 478
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 479
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 480
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 481
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 482
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 483
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 484
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 485
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 486
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 487
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 488
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 489
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 490
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 491
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 492
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 493
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 494
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 495
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 496
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 497
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 498
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 499
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 500
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 501
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 502
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 503
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 504
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 505
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 506
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 507
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 508
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 509
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 510
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 511
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 512
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 513
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 514
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 515
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 516
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 517
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 518
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 519
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 520
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 521
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 522
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 523
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 524
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 525
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 526
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 527
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 528
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 529
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 530
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 531
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 532
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 533
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 534
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 535
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 536
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 537
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 538
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 539
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 540
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 541
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 542
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 543
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 544
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 545
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 546
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 547
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 548
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 549
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 550
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 551
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 552
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 553
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 554
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 555
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 556
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 557
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 558
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 559
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 560
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 561
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 562
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 563
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 564
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 565
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 566
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 567
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 568
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 569
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 570
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 571
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 572
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 573
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 574
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 575
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 576
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 577
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 578
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 579
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 580
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 581
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 582
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 583
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 584
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 585
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 586
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 587
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 588
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 589
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 590
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 591
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 592
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 593
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 594
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 595
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 596
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 597
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 598
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 599
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 600
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 601
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 602
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 603
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 604
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 605
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 606
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 607
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 608
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 609
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 610
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 611
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 612
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 613
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 614
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 615
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 616
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 617
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 618
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 619
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 620
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 621
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 622
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 623
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 624
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 625
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 626
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 627
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 628
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 629
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 630
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 631
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 632
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 633
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 634
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 635
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 636
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 637
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 638
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 639
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 640
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 641
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 642
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 643
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 644
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 645
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 646
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 647
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 648
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 649
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 650
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 651
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 652
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 653
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 654
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 655
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 656
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 657
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 658
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 659
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 660
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 661
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 662
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 663
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 664
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 665
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 666
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 667
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 668
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 669
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 670
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 671
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 672
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 673
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 674
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 675
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 676
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 677
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 678
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 679
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 680
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 681
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 682
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 683
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 684
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 685
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 686
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 687
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 688
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 689
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 690
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 691
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 692
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 693
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 694
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 695
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 696
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 697
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 698
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 699
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 700
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 701
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 702
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 703
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 704
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 705
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 706
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 707
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 708
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 709
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 710
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 711
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 712
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 713
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 714
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 715
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 716
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 717
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 718
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 719
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 720
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 721
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 722
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 723
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 724
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 725
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 726
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 727
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 728
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 729
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 730
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 731
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 732
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 733
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 734
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 735
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 736
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 737
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 738
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 739
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 740
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 741
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 742
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 743
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 744
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 745
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 746
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 747
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 748
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 749
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 750
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 751
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 752
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 753
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 754
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 755
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 756
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 757
# Message sent:
# ...
#     Partition: 0
#     Offset: 808
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 809
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 810
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 811
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 812
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 813
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 814
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 815
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 816
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 817
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 818
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 819
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 820
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 821
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 822
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 823
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 824
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 825
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 826
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 827
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 828
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 829
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 830
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 831
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 832
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 833
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 834
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 835
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 836
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 837
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 838
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 839
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 840
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 841
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 842
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 843
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 844
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 845
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 846
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 847
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 848
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 849
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 850
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 851
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 852
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 853
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 854
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 855
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 856
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 857
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 858
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 859
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 860
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 861
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 862
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 863
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 864
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 865
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 866
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 867
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 868
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 869
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 870
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 871
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 872
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 873
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 874
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 875
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 876
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 877
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 878
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 879
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 880
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 881
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 882
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 883
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 884
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 885
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 886
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 887
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 888
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 889
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 890
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 891
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 892
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 893
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 894
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 895
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 896
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 897
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 898
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 899
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 900
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 901
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 902
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 903
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 904
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 905
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 906
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 907
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 908
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 909
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 910
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 911
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 912
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 913
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 914
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 915
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 916
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 917
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 918
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 919
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 920
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 921
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 922
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 923
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 924
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 925
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 926
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 927
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 928
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 929
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 930
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 931
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 932
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 933
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 934
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 935
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 936
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 937
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 938
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 939
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 940
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 941
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 942
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 943
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 944
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 945
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 946
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 947
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 948
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 949
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 950
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 951
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 952
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 953
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 954
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 955
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 956
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 957
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 958
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 959
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 960
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 961
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 962
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 963
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 964
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 965
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 966
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 967
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 968
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 969
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 970
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 971
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 972
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 973
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 974
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 975
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 976
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 977
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 978
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 979
# Message sent:
#     Topic: "HotalingMichael-accelerations"
#     Partition: 0
#     Offset: 980
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-ce8fbd732267> in <module>
#       2 for index,row in df_accelerations.iterrows():
#       3     current_offset = row['offset']
# ----> 4     time.sleep(current_offset - last_offset)
#       5     send_acceleration_data(index)
#       6     last_offset = current_offset
#
# KeyboardInterrupt:
